# %% [markdown]
# # Import Packages

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Load Dataset

# %%
confirmed = pd.read_csv('confirmed.csv')
recovered = pd.read_csv('recovered.csv')
death = pd.read_csv('death.csv')

# %%
confirmed.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  \
# 0        0        0        0  ...     423     444     484      521      555
# 1        0        0        0  ...     383     400     409      416      433
# 2        0        0        0  ...    1468    1572    1666     1761     1825
# 3        0        0        0  ...     545     564     583      601      601
# 4        0        0        0  ...      17      19      19       19       19
#
# ...

# %%
recovered.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  \
# 0        0        0        0  ...      18      29      32       32       32
# 1        0        0        0  ...     131     154     165      182      197
# 2        0        0        0  ...     113     237     347      405      460
# 3        0        0        0  ...      39      52      58       71       71
# 4        0        0        0  ...       2       2       2        2        4
#
# ...

# %%
death.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  \
# 0        0        0        0  ...      14      14      15       15       18
# 1        0        0        0  ...      22      22      23       23       23
# 2        0        0        0  ...     193     205     235      256      275
# 3        0        0        0  ...      22      23      25       26       26
# 4        0        0        0  ...       2       2       2        2        2
#
# ...

# %% [markdown]
# ## Drop Columns (Data Cleaning)

# %%
confirmed=confirmed.drop(['Province/State','Lat','Long'],axis=1)

# %%
recovered=recovered.drop(['Province/State','Lat','Long'],axis=1)

# %%
death=death.drop(['Province/State','Lat','Long'],axis=1)

# %%
confirmed.head(10)
# Out:
#         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          Afghanistan        0        0        0        0        0        0
# 1              Albania        0        0        0        0        0        0
# 2              Algeria        0        0        0        0        0        0
# 3              Andorra        0        0        0        0        0        0
# 4               Angola        0        0        0        0        0        0
# 5  Antigua and Barbuda        0        0        0        0        0        0
# 6            Argentina        0        0        0        0        0        0
# 7              Armenia        0        0        0        0        0        0
# 8            Australia        0        0        0        0        0        0
# 9            Australia        0        0        0        0        3        4
#
#    1/28/20  1/29/20  1/30/20  ...  4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  \
# ...

# %% [markdown]
# ## GroupBy the Country Name

# %%
confirmed = confirmed.groupby(confirmed['Country/Region']).aggregate('sum')

# %%
confirmed.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/7/20  4/8/20  \
# ...

# %%
recovered = recovered.groupby(recovered['Country/Region']).aggregate('sum')

# %%
recovered.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        0        0
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/7/20  4/8/20  \
# ...

# %%
death = death.groupby(death['Country/Region']).aggregate('sum')

# %%
death.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/7/20  4/8/20  4/9/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...      14      14      15
# Albania               0        0        0  ...      22      22      23
# Algeria               0        0        0  ...     193     205     235
# Andorra               0        0        0  ...      22      23      25
# Angola                0        0        0  ...       2       2       2
#
# ...

# %% [markdown]
# ## Transpose the Dataset

# %%
confirmed=confirmed.T
death=death.T
recovered=recovered.T

# %%
confirmed.head()
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 1/22/20                           0          0        0          0        0
# 1/23/20                           0          0        0          0        0
# 1/24/20                           0          0        0          0        0
# 1/25/20                           0          0        0          0        0
# 1/26/20                           0          0        0          4        0
#
# Country/Region  ...  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# ...

# %%
confirmed.tail(10)
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 4/7/20                  423      383     1468      545      17
# 4/8/20                  444      400     1572      564      19
# 4/9/20                  484      409     1666      583      19
# 4/10/20                 521      416     1761      601      19
# 4/11/20                 555      433     1825      601      19
# 4/12/20                 607      446     1914      638      19
# 4/13/20                 665      467     1983      646      19
# 4/14/20                 714      475     2070      659      19
# 4/15/20                 784      494     2160      673      19
# 4/16/20                 840      518     2268      673      19
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 4/7/20                           19       1628      853       5895    12639
# 4/8/20                           19       1715      881       6010    12942
# ...

# %% [markdown]
# ## Total New Cases

# %%
new_cases = confirmed.copy()
for day in range(1,len(confirmed)):
    new_cases.iloc[day]=confirmed.iloc[day]-confirmed.iloc[day-1]

# %%
confirmed.tail()
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 4/12/20                 607      446     1914      638      19
# 4/13/20                 665      467     1983      646      19
# 4/14/20                 714      475     2070      659      19
# 4/15/20                 784      494     2160      673      19
# 4/16/20                 840      518     2268      673      19
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 4/12/20                          21       2142     1013       6315    13945
# 4/13/20                          23       2208     1039       6351    14041
# 4/14/20                          23       2277     1067       6415    14226
# 4/15/20                          23       2443     1111       6440    14336
# 4/16/20                          23       2571     1159       6462    14476
#
# Country/Region  ...  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# ...

# %%
new_cases.tail()
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 4/12/20                  52       13       89       37       0
# 4/13/20                  58       21       69        8       0
# 4/14/20                  49        8       87       13       0
# 4/15/20                  70       19       90       14       0
# 4/16/20                  56       24      108        0       0
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 4/12/20                           0        167       46         12      139
# 4/13/20                           2         66       26         36       96
# 4/14/20                           0         69       28         64      185
# 4/15/20                           0        166       44         25      110
# 4/16/20                           0        128       48         22      140
#
# Country/Region  ...  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# ...

# %% [markdown]
# ## Growth Rate

# %%
growth_rate = confirmed.copy()
for day in range(1,len(confirmed)):
    growth_rate.iloc[day]=(new_cases.iloc[day]/new_cases.iloc[day-1])*100

# %%
new_cases.tail()
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 4/12/20                  52       13       89       37       0
# 4/13/20                  58       21       69        8       0
# 4/14/20                  49        8       87       13       0
# 4/15/20                  70       19       90       14       0
# 4/16/20                  56       24      108        0       0
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 4/12/20                           0        167       46         12      139
# 4/13/20                           2         66       26         36       96
# 4/14/20                           0         69       28         64      185
# 4/15/20                           0        166       44         25      110
# 4/16/20                           0        128       48         22      140
#
# Country/Region  ...  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# ...

# %%
growth_rate.tail()
# Out:
# Country/Region  Afghanistan     Albania     Algeria     Andorra  Angola  \
# 4/12/20          152.941176   76.470588  139.062500         inf     NaN
# 4/13/20          111.538462  161.538462   77.528090   21.621622     NaN
# 4/14/20           84.482759   38.095238  126.086957  162.500000     NaN
# 4/15/20          142.857143  237.500000  103.448276  107.692308     NaN
# 4/16/20           80.000000  126.315789  120.000000    0.000000     NaN
#
# Country/Region  Antigua and Barbuda   Argentina     Armenia   Australia  \
# 4/12/20                         0.0         inf  153.333333   13.636364
# 4/13/20                         inf   39.520958   56.521739  300.000000
# 4/14/20                         0.0  104.545455  107.692308  177.777778
# 4/15/20                         NaN  240.579710  157.142857   39.062500
# 4/16/20                         NaN   77.108434  109.090909   88.000000
#
# Country/Region     Austria  ...  United Kingdom     Uruguay  Uzbekistan  \
# ...

# %% [markdown]
# ## Overall Growth Rate

# %%
active = confirmed.copy()
for day in range(0,len(confirmed)):
    active.iloc[day]=confirmed.iloc[day]-death.iloc[day]-recovered.iloc[day]
overall_growth_rate = confirmed.copy()
for day in range(1,len(confirmed)):
    overall_growth_rate.iloc[day]=((active.iloc[day]-active.iloc[day-1])/active.iloc[day-1])*100
overall_growth_rate.tail()
# Out:
# Country/Region  Afghanistan   Albania   Algeria   Andorra    Angola  \
# 4/12/20           10.297030 -3.286385 -5.504587 -4.563492  0.000000
# 4/13/20            9.874327  2.912621  3.786408  1.663202  0.000000
# 4/14/20            6.372549 -4.245283 -1.496726  2.249489 -7.692308
# 4/15/20            9.984639  7.389163  5.982906 -5.800000  0.000000
# 4/16/20            5.586592 -1.376147  1.881720  0.000000  0.000000
#
# Country/Region  Antigua and Barbuda  Argentina   Armenia  Australia  \
# 4/12/20                    0.000000   9.090909  2.816901   0.202703
# 4/13/20                   10.526316   0.757576  1.369863   0.786694
# 4/14/20                  -14.285714   1.253133 -3.439803  -7.069581
# 4/15/20                    0.000000   7.425743  1.399491   0.575954
# 4/16/20                   -5.555556   5.126728 -1.756587  -3.507516
#
# Country/Region    Austria  ...  United Kingdom    Uruguay  Uzbekistan  \
# 4/12/20         -3.743627  ...        6.619089 -11.355311   10.263523
# ...

# %% [markdown]
# ## Death Rate

# %%
death_rate=confirmed.copy()
for day in range(1,len(confirmed)):
    death_rate.iloc[day]=(death.iloc[day]/confirmed.iloc[day])*100
death_rate.tail()
# Out:
# Country/Region  Afghanistan   Albania    Algeria   Andorra     Angola  \
# 4/12/20            2.965404  5.156951  15.308255  4.545455  10.526316
# 4/13/20            3.157895  4.925054  15.784165  4.489164  10.526316
# 4/14/20            3.221289  5.052632  15.748792  4.704097  10.526316
# 4/15/20            3.188776  5.060729  15.555556  4.903418  10.526316
# 4/16/20            3.571429  5.019305  15.343915  4.903418  10.526316
#
# Country/Region  Antigua and Barbuda  Argentina   Armenia  Australia   Austria  \
# 4/12/20                    9.523810   4.201681  1.283317   0.950119  2.509860
# 4/13/20                    8.695652   4.393116  1.347449   0.960479  2.620896
# 4/14/20                    8.695652   4.479578  1.499531   0.966485  2.699283
# 4/15/20                    8.695652   4.543594  1.530153   0.978261  2.741350
# 4/16/20                   13.043478   4.472968  1.553063   0.974930  2.832274
#
# ...

# %% [markdown]
# ## Data Vistualization

# %% [markdown]
# ## Confirmed Cases

# %% [markdown]
# ### Total Confirmed Cases in Countries

# %%
countries=['India','Pakistan','Afghanistan','Italy']
ax=plt.subplot()
ax.set_facecolor('black')
ax.figure.set_facecolor('#121212')
ax.tick_params(axis='x',color='white')
ax.tick_params(axis='y',color='white')
ax.set_title('COVID-19 Total Confirmed Cases by country',color='white')
for country in countries:
    confirmed[country][30:].plot(label=country)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Bar Chart Plotting

# %%
countries=['India','Pakistan','Afghanistan','Italy']
for country in countries:
    ax=plt.subplot()
    ax.set_facecolor('black')
    ax.figure.set_facecolor('#121212')
    ax.tick_params(axis='x',color='white')
    ax.tick_params(axis='y',color='white')
    ax.set_title(f'COVID-19 Total Confirmed Cases Growth Rate {country}',color='white')
    growth_rate[country].plot.bar()
    plt.show()

# %% [markdown]
# ## Death Rate

# %%
countries=['China','India','Pakistan','Afghanistan','Italy']
for country in countries:
    ax=plt.subplot()
    ax.set_facecolor('black')
    ax.figure.set_facecolor('#121212')
    ax.tick_params(axis='x',color='white')
    ax.tick_params(axis='y',color='white')
    ax.set_title(f'COVID-19 Total Confirmed Cases Death Rate {country}',color='white')
    death_rate[country].plot.bar()
    plt.show()

# %% [markdown]
# ## Estimated Confirmed Cases

# %%
simulated_gro_rate = 0.05
dates = pd.date_range(start='3/23/2020',periods=40,freq='D')
dates = pd.Series(dates)
dates = dates.dt.strftime('%m%d%Y')
simulated = confirmed.copy()
simulated = simulated.append(pd.DataFrame(index=dates))
simulated.tail(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#           Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# 04222020          NaN      NaN      NaN      NaN     NaN                  NaN
# 04232020          NaN      NaN      NaN      NaN     NaN                  NaN
# 04242020          NaN      NaN      NaN      NaN     NaN                  NaN
# 04252020          NaN      NaN      NaN      NaN     NaN                  NaN
# 04262020          NaN      NaN      NaN      NaN     NaN                  NaN
# 04272020          NaN      NaN      NaN      NaN     NaN                  NaN
# 04282020          NaN      NaN      NaN      NaN     NaN                  NaN
# ...

# %%
ax=plt.subplot()
ax.set_facecolor('black')
ax.figure.set_facecolor('#121212')
ax.tick_params(axis='x',color='white')
ax.tick_params(axis='y',color='white')
ax.set_title('Future Simulation for Italy',color='white')
simulated['Italy'].plot()
plt.show()
